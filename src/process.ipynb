# %%
import jax.numpy as jnp
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import mplcursors

from utils import calc_prf

# %%
eval = jnp.load('../data/eval.npz')
z = eval['z']
energy = eval['energy']
labels = eval['labels']

# %%
precision, recall, f1 = calc_prf(energy, labels)
print(f'Precision: {precision}')
print(f'Recall: {recall}')
print(f'F1: {f1}')
# Out:
# Threshold: 0.10961027443408966
# Precision: 0.34417286574566064
# Recall: 0.34957544357408665
# F1: 0.3468531183223431

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(z[:, 2], z[:, 0], z[:, 1], c=labels, cmap='cool', s=1)
ax.set_xlabel('Encoded')
ax.set_ylabel('Euclidean')
ax.set_zlabel('Cosine')

mplcursors.cursor(sc, hover=True)
plt.show()
